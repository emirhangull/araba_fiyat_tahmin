# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv("results.csv")
df2 = pd.read_csv("retry_results_partial.csv")

# %%
df = pd.concat([df1,df2])
df.shape
# Out:
# (2110, 24)

# %%
a = set(df.url)
b = set(pd.read_csv("volkswagen_passat-1-6-tdi-bluemotion_2018_43_sayfa_ilan_linkleri.csv").Ilan_Linkleri)

# %%
len(b)
# Out:
# 2120

# %%
a==b
# Out:
# False

# %%
ortaklar = a.intersection(b)
len(ortaklar)
# Out:
# 2110

# %%
farklar=b-a
len(farklar)
# Out:
# 10

# %%
df
# Out:
#                                                     url         fiyat  \
# 0     https://www.arabam.com/ilan/galeriden-satilik-...  1.425.000 TL
# 1     https://www.arabam.com/ilan/galeriden-satilik-...  1.499.000 TL
# 2     https://www.arabam.com/ilan/galeriden-satilik-...    995.000 TL
# 3     https://www.arabam.com/ilan/galeriden-satilik-...  1.170.500 TL
# 4     https://www.arabam.com/ilan/galeriden-satilik-...  1.249.000 TL
# ...                                                 ...           ...
# 1054  https://www.arabam.com/ilan/sahibinden-satilik...    675.000 TL
# 1055  https://www.arabam.com/ilan/galeriden-satilik-...  1.315.000 TL
# 1056  https://www.arabam.com/ilan/galeriden-satilik-...  1.358.900 TL
# 1057  https://www.arabam.com/ilan/sahibinden-satilik...  1.433.000 TL
# 1058  https://www.arabam.com/ilan/galeriden-satilik-...           NaN
#
#          ilan_no      ilan_tarihi       marka    seri  \
# 0     30187292.0  27 Haziran 2025  Volkswagen  Passat
# ...

# %%
son10df = pd.read_csv("son10link.csv")
df = pd.concat([df,son10df])

# %%
df
# Out:
#                                                   url         fiyat  \
# 0   https://www.arabam.com/ilan/galeriden-satilik-...  1.425.000 TL
# 1   https://www.arabam.com/ilan/galeriden-satilik-...  1.499.000 TL
# 2   https://www.arabam.com/ilan/galeriden-satilik-...    995.000 TL
# 3   https://www.arabam.com/ilan/galeriden-satilik-...  1.170.500 TL
# 4   https://www.arabam.com/ilan/galeriden-satilik-...  1.249.000 TL
# ..                                                ...           ...
# 4   https://www.arabam.com/ilan/galeriden-satilik-...  1.090.000 TL
# 5   https://www.arabam.com/ilan/sahibinden-satilik...  1.400.000 TL
# 6   https://www.arabam.com/ilan/galeriden-satilik-...    985.000 TL
# 7   https://www.arabam.com/ilan/galeriden-satilik-...    770.000 TL
# 8   https://www.arabam.com/ilan/galeriden-satilik-...  1.150.000 TL
#
#        ilan_no      ilan_tarihi       marka    seri  \
# 0   30187292.0  27 Haziran 2025  Volkswagen  Passat
# ...

# %%
a = set(df.url)
b = set(pd.read_csv("volkswagen_passat-1-6-tdi-bluemotion_2018_43_sayfa_ilan_linkleri.csv").Ilan_Linkleri)

# %%
farklar = b-a
farklar
# Out:
# {'https://www.arabam.com/ilan/sahibinden-satilik-volkswagen-passat-1-6-tdi-bluemotion-comfortline/sahibinden-volkswagen-passat-1-6-tdi-bluemotion-comfortline-2015-model/29768546'}

# %%
df
# Out:
#                                                   url         fiyat  \
# 0   https://www.arabam.com/ilan/galeriden-satilik-...  1.425.000 TL
# 1   https://www.arabam.com/ilan/galeriden-satilik-...  1.499.000 TL
# 2   https://www.arabam.com/ilan/galeriden-satilik-...    995.000 TL
# 3   https://www.arabam.com/ilan/galeriden-satilik-...  1.170.500 TL
# 4   https://www.arabam.com/ilan/galeriden-satilik-...  1.249.000 TL
# ..                                                ...           ...
# 4   https://www.arabam.com/ilan/galeriden-satilik-...  1.090.000 TL
# 5   https://www.arabam.com/ilan/sahibinden-satilik...  1.400.000 TL
# 6   https://www.arabam.com/ilan/galeriden-satilik-...    985.000 TL
# 7   https://www.arabam.com/ilan/galeriden-satilik-...    770.000 TL
# 8   https://www.arabam.com/ilan/galeriden-satilik-...  1.150.000 TL
#
#        ilan_no      ilan_tarihi       marka    seri  \
# 0   30187292.0  27 Haziran 2025  Volkswagen  Passat
# ...

# %%
df_temp = pd.read_csv("sonbasbalink.csv")
df = pd.concat([df,df_temp])
df
# Out:
#                                                   url         fiyat  \
# 0   https://www.arabam.com/ilan/galeriden-satilik-...  1.425.000 TL
# 1   https://www.arabam.com/ilan/galeriden-satilik-...  1.499.000 TL
# 2   https://www.arabam.com/ilan/galeriden-satilik-...    995.000 TL
# 3   https://www.arabam.com/ilan/galeriden-satilik-...  1.170.500 TL
# 4   https://www.arabam.com/ilan/galeriden-satilik-...  1.249.000 TL
# ..                                                ...           ...
# 5   https://www.arabam.com/ilan/sahibinden-satilik...  1.400.000 TL
# 6   https://www.arabam.com/ilan/galeriden-satilik-...    985.000 TL
# 7   https://www.arabam.com/ilan/galeriden-satilik-...    770.000 TL
# 8   https://www.arabam.com/ilan/galeriden-satilik-...  1.150.000 TL
# 0                                                   6  1.150.000 TL
#
#        ilan_no      ilan_tarihi       marka    seri  \
# 0   30187292.0  27 Haziran 2025  Volkswagen  Passat
# ...

# %%
x = set(df.url)
y = set(pd.read_csv("volkswagen_passat-1-6-tdi-bluemotion_2018_43_sayfa_ilan_linkleri.csv").Ilan_Linkleri)

# %%
len(x.intersection(y))
# Out:
# 2119

# %%
df.to_csv("df.csv", index=False, encoding="utf-8")
